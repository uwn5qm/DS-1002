# %% [markdown]
# <a href="https://colab.research.google.com/github/uwn5qm/DS-1002/blob/main/Assignments/06_Pandas_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas exercises 1
#
# 1. Import dependencies

# %%
import pandas as pd

# %% [markdown]
# ---

# %%
list = [98, 24, 46, 87, 33]

# %% [markdown]
# 2. Convert `list` to a pandas series using `pd.Series`

# %%
series = pd.Series(list)
series
# Out:
# 0    98
# 1    24
# 2    46
# 3    87
# 4    33
# dtype: int64

# %% [markdown]
# 3. Take the above series and add an index that starts at 2 and steps by 3

# %%
series.index = ['2','5','8','11','14']
series
# Out:
# 2     98
# 5     24
# 8     46
# 11    87
# 14    33
# dtype: int64

# %% [markdown]
# 4. Create a dictionary of 4 names, ages, and careers
# Convert this dictionary to a pandas dataframe: `df`.
# Print the dataframe.

# %%
dict = {'names': ('steve','randy','travis','luke'),
        'ages': (30,29,28,27),
        'careers': ('garbageman','salesman','lawyer','businessman')}
df = pd.DataFrame(dict)
df
# Out:
#     names  ages      careers
# 0   steve    30   garbageman
# 1   randy    29     salesman
# 2  travis    28       lawyer
# 3    luke    27  businessman

# %% [markdown]
# 5. Name the index of `df` 'participant_id'.
# Print `df`.

# %%
df.index
df.index.name = 'participant_id'
df
# Out:
#                  names  ages      careers
# participant_id
# 0                steve    30   garbageman
# 1                randy    29     salesman
# 2               travis    28       lawyer
# 3                 luke    27  businessman

# %% [markdown]
# 6. Use a pandas function to determine the data types of the columns of `df`.

# %%
df.dtypes
# Out:
# names      object
# ages        int64
# careers    object
# dtype: object

# %% [markdown]
# 7. Using bracket notation, reference column `name`

# %%
df['names']
# Out:
# participant_id
# 0     steve
# 1     randy
# 2    travis
# 3      luke
# Name: names, dtype: object

# %% [markdown]
# 8. Using dot notation, reference column `name`

# %%
df.names
# Out:
# participant_id
# 0     steve
# 1     randy
# 2    travis
# 3      luke
# Name: names, dtype: object

# %% [markdown]
# 8. Reference column `name` and have it returned in a dataframe.

# %%
ndf = pd.DataFrame(df.names)
ndf
# Out:
#                  names
# participant_id
# 0                steve
# 1                randy
# 2               travis
# 3                 luke

# %% [markdown]
# 9. Show the 3rd element in column `career`.

# %%
df.careers.values[2]
# Out:
# 'lawyer'

# %% [markdown]
# 10.  Load the `iris` dataset that we used in class.  Use `iris` as the name of your data frame.

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 11.  What is the correlation between the variables `sepal_length` and `sepal_width` for all the irises?

# %%
iris[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length       1.00000     -0.11757
# sepal_width       -0.11757      1.00000

# %% [markdown]
# 12.  Which of the three species has the highest correlation between `sepal_length` and `sepal_width`?  Show any calculations you use to support your answer.

# %%
setosa=iris.iloc[:50]
versicolor=iris.iloc[50:101]
virginica=iris.iloc[100:151]
print(setosa[['sepal_length','sepal_width']].corr())
print(versicolor[['sepal_length','sepal_width']].corr())
print(virginica[['sepal_length','sepal_width']].corr())
# this shows us that setosa has the highest correlation between sepal length and sepal width
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.742547
# sepal_width       0.742547     1.000000
#               sepal_length  sepal_width
# sepal_length      1.000000     0.532054
# sepal_width       0.532054     1.000000
#               sepal_length  sepal_width
# sepal_length      1.000000     0.457228
# sepal_width       0.457228     1.000000

# %% [markdown]
# 13.  Among the four variables, the two that are most negatively correlated (overall) are `sepal_width` and `petal_length`.  (How do we know this?)  Determine the same thing but for each species separately:  for each species, which two variables have the most negative correlation?  Again, include calculations to support your answer.

# %%
iris.corr()
# this is how we know that sepal width and petal length are the most negatively correlated
# Out:
# <ipython-input-15-e9069aea2b7f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
#setosa: sepal width and petal length have the lowest correlation
print(setosa[['sepal_length','sepal_width']].corr())
print(setosa[['sepal_length','petal_length']].corr())
print(setosa[['sepal_length','petal_width']].corr())
print(setosa[['sepal_width','petal_length']].corr())
print(setosa[['sepal_width','petal_width']].corr())
print(setosa[['petal_length','petal_width']].corr())
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.742547
# sepal_width       0.742547     1.000000
#               sepal_length  petal_length
# sepal_length      1.000000      0.267176
# petal_length      0.267176      1.000000
#               sepal_length  petal_width
# sepal_length      1.000000     0.278098
# petal_width       0.278098     1.000000
#               sepal_width  petal_length
# sepal_width        1.0000        0.1777
# petal_length       0.1777        1.0000
#              sepal_width  petal_width
# sepal_width     1.000000     0.232752
# petal_width     0.232752     1.000000
#               petal_length  petal_width
# petal_length       1.00000      0.33163
# petal_width        0.33163      1.00000

# %%
#versicolor: petal width and sepal length have the lowest correlation
print(versicolor[['sepal_length','sepal_width']].corr())
print(versicolor[['sepal_length','petal_length']].corr())
print(versicolor[['sepal_length','petal_width']].corr())
print(versicolor[['sepal_width','petal_length']].corr())
print(versicolor[['sepal_width','petal_width']].corr())
print(versicolor[['petal_length','petal_width']].corr())
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.532054
# sepal_width       0.532054     1.000000
#               sepal_length  petal_length
# sepal_length      1.000000      0.710727
# petal_length      0.710727      1.000000
#               sepal_length  petal_width
# sepal_length      1.000000     0.480244
# petal_width       0.480244     1.000000
#               sepal_width  petal_length
# sepal_width      1.000000      0.590759
# petal_length     0.590759      1.000000
#              sepal_width  petal_width
# sepal_width     1.000000     0.644002
# petal_width     0.644002     1.000000
#               petal_length  petal_width
# petal_length      1.000000     0.832035
# petal_width       0.832035     1.000000

# %%
#virginica: petal width and sepal length have the lowest correlation
print(virginica[['sepal_length','sepal_width']].corr())
print(virginica[['sepal_length','petal_length']].corr())
print(virginica[['sepal_length','petal_width']].corr())
print(virginica[['sepal_width','petal_length']].corr())
print(virginica[['sepal_width','petal_width']].corr())
print(virginica[['petal_length','petal_width']].corr())
# Out:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.457228
# sepal_width       0.457228     1.000000
#               sepal_length  petal_length
# sepal_length      1.000000      0.864225
# petal_length      0.864225      1.000000
#               sepal_length  petal_width
# sepal_length      1.000000     0.281108
# petal_width       0.281108     1.000000
#               sepal_width  petal_length
# sepal_width      1.000000      0.401045
# petal_length     0.401045      1.000000
#              sepal_width  petal_width
# sepal_width     1.000000     0.537728
# petal_width     0.537728     1.000000
#               petal_length  petal_width
# petal_length      1.000000     0.322108
# petal_width       0.322108     1.000000

# %% [markdown]
# 14.  Once again, the variables `sepal_width` and `petal_length` are negatively correlated.  But for each individual species, these two variables are positively correlated.  How is this possible?  Explain this phenomenon.  Use a data visualization if it helps.

# %%
import matplotlib.pyplot as plt
sepal_width = iris['sepal_width']
petal_length = iris['petal_length']
plt.scatter(sepal_width, petal_length)
# as we can see, there is a strong overall negative correlation between sepal
# width and petal length for the species overall, but for each species in particular
# there is a positive (albeit low) correlation between the two
